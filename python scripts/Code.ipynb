# %%
import numpy as np

# %%
import pandas as pd
df = pd.read_csv("/content/Bonus_Data - Bonus_Data.csv")
df.head()
# Out:
#                 Restaurant Name  Rating  Price for 2  \
# 0           The Cake Warehouse'     0.0            3
# 1                 HORI LAL PAN'     0.0           50
# 2  Daddy's Delicious Food House     0.0           90
# 3             Dream Food Point'     0.0          100
# 4       Bablu De Chole Bhature'     0.0          100
#
#                         Cuisines                           Coordinates  \
# 0                     ['Bakery']             28.669413,77.195265999999
# 1                       ['Paan']                 28.7344512,77.1141371
# 2                     ['Snacks']                 28.7431512,77.1967227
# 3        ['Fast Food', 'Indian']       28.334930868488,77.327502474413
# 4  ['Fast Food', 'North Indian']  28.472435257398544,77.31496234979066
#
#                                                 Menu  \
# 0  ,[['Pineapple Cake', 'Cake', 350.0, 1], ['Blac...
# 1  ,[['Meetha patta sada', 'Saada Paan', 40.0, 1]...
# ...

# %%
df
# Out:
#                     Restaurant Name  Rating  Price for 2  \
# 0               The Cake Warehouse'     0.0            3
# 1                     HORI LAL PAN'     0.0           50
# 2      Daddy's Delicious Food House     0.0           90
# 3                 Dream Food Point'     0.0          100
# 4           Bablu De Chole Bhature'     0.0          100
# ..                              ...     ...          ...
# 895                    Tokyo Table'     0.0         1000
# 896     Noshi - Yum Asian Delivery'     4.3         1000
# 897    Enoki - Fresh Asian Kitchen'     4.4         1000
# 898  TDI Club Retreat Kundli Hotel'     0.0         1000
# 899                 Chicken Corner'     0.0         1100
#
#                              Cuisines                           Coordinates  \
# 0                          ['Bakery']             28.669413,77.195265999999
# 1                            ['Paan']                 28.7344512,77.1141371
# ...

# %%
def run(region):
    for colname in  df:
        ans = 0
        if(colname == "District of Reference(To be deleted later)"):
            sum=0
            count=0
            for (index,s) in enumerate(df[colname]):
                if( s == region):
                    sum +=df.iloc[index]["Rating"]
                    count+=1
            print(sum)
            print(count)
            if(count == 0):
                break
            ans = sum/count
            
            print(ans)
            for (index,s) in enumerate(df[colname]):
                if( s == region and df.iloc[index]["Rating"] == 0):
                    df.loc[index,"Rating"] = ans

# %%
run("North Delhi")
run("South Delhi")

run("East Delhi")
run("West Delhi")

run("North West Delhi")
run("South West Delhi")

run("North East Delhi")
run("South East Delhi")

run("Central Delhi")
run("Shahdara ")

run("New Delhi")

# sum = 0
#         count=0
#         for s in df[colname].values:
#             if( s == "North Delhi"):
#                 print(df.iloc[index]["Rating"])
#                 sum += df.iloc[index]["Rating"]
#                 count+=1
                
#         ans = sum/count
#         print(ans)
# df
# Out:
# 136.8
# 79
# 1.7316455696202533
# 255.90000000000003
# 87
# 2.941379310344828
# 274.90000000000015
# 79
# 3.4797468354430396
# 295.40000000000003
# 77
# 3.836363636363637
# 242.10000000000002
# 88
# 2.751136363636364
# 144.00000000000003
# 50
# 2.880000000000001
# 170.50000000000003
# 84
# 2.029761904761905
# 425.7000000000001
# 113
# 3.7672566371681424
# 286.6
# 91
# 3.14945054945055
# 0
# 0
# 299.0
# 89
# 3.359550561797753

# %%
df
# Out:
#                     Restaurant Name    Rating  Price for 2  \
# 0               The Cake Warehouse'  3.149451            3
# 1                     HORI LAL PAN'  1.731646           50
# 2      Daddy's Delicious Food House  1.731646           90
# 3                 Dream Food Point'  2.941379          100
# 4           Bablu De Chole Bhature'  2.941379          100
# ..                              ...       ...          ...
# 895                    Tokyo Table'  2.880000         1000
# 896     Noshi - Yum Asian Delivery'  4.300000         1000
# 897    Enoki - Fresh Asian Kitchen'  4.400000         1000
# 898  TDI Club Retreat Kundli Hotel'  1.731646         1000
# 899                 Chicken Corner'  2.751136         1100
#
#                              Cuisines                           Coordinates  \
# 0                          ['Bakery']             28.669413,77.195265999999
# 1                            ['Paan']                 28.7344512,77.1141371
# ...

# %%
df["Rating"].value_counts()
# Out:
# 4.000000    86
# 4.100000    81
# 4.200000    77
# 4.300000    76
# 3.900000    61
# 3.800000    52
# 4.400000    45
# 1.731646    42
# 2.029762    41
# 4.500000    35
# 4.600000    28
# 2.751136    27
# 3.700000    26
# 2.941379    25
# 3.600000    18
# 3.359551    17
# 3.149451    17
# 2.880000    16
# 3.300000    16
# 3.500000    15
# 3.479747    11
# 0.000000    10
# 3.767257     9
# 3.200000     8
# 3.400000     8
# 3.000000     7
# 4.700000     7
# 4.900000     6
# 2.800000     5
# 3.836364     5
# 4.800000     5
# 5.000000     4
# 3.100000     4
# 2.300000     3
# 2.900000     2
# 2.400000     2
# 2.100000     1
# 2.200000     1
# 2.500000     1
# Name: Rating, dtype: int64

# %%
df.to_csv("updated_Bonus.csv")

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("updated_Bonus.csv")
df.head()
# Out:
#    Unnamed: 0               Restaurant Name    Rating  Price for 2  \
# 0           0           The Cake Warehouse'  3.149451            3
# 1           1                 HORI LAL PAN'  1.731646           50
# 2           2  Daddy's Delicious Food House  1.731646           90
# 3           3             Dream Food Point'  2.941379          100
# 4           4       Bablu De Chole Bhature'  2.941379          100
#
#                         Cuisines                           Coordinates  \
# 0                     ['Bakery']             28.669413,77.195265999999
# 1                       ['Paan']                 28.7344512,77.1141371
# 2                     ['Snacks']                 28.7431512,77.1967227
# 3        ['Fast Food', 'Indian']       28.334930868488,77.327502474413
# 4  ['Fast Food', 'North Indian']  28.472435257398544,77.31496234979066
#
#                                                 Menu  \
# 0  ,[['Pineapple Cake', 'Cake', 350.0, 1], ['Blac...
# ...

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import seaborn as sns
X_train = df[['Rating', 'Price for 2']]
clustering = DBSCAN(eps=12.5, min_samples=4).fit(X_train)
DBSCAN_dataset = X_train.copy()
DBSCAN_dataset.loc[:,'Cluster'] = clustering.labels_ 
DBSCAN_dataset.Cluster.value_counts().to_frame()
outliers = DBSCAN_dataset[DBSCAN_dataset['Cluster']==-1]

fig2, (axes) = plt.subplots(1,2,figsize=(12,5))

sns.scatterplot('Rating', 'Price for 2',

                data=DBSCAN_dataset[DBSCAN_dataset['Cluster']!=-1],

                hue='Cluster', ax=axes[0], palette='Set2', legend='full', s=200)
axes[0].scatter(outliers['Rating'], outliers['Price for 2'], s=10, label='outliers', c="k")
axes[0].legend()
plt.setp(axes[0].get_legend().get_texts(), fontsize='12')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from joblib import Parallel, delayed
import joblib
  
  
# Save the model as a pickle in a file
joblib.dump(clustering, 'model1.pkl')
# Out:
# ['model1.pkl']

# %%
# most fo the restarants have their price range for 2 between 0 -400 and 
# the rating can also be analysed that most it between 3.5 - 4.5
#

# %%
from sklearn import preprocessing
encoding = preprocessing.LabelEncoder()
df['District of Reference(To be deleted later)']= encoding.fit_transform(df['District of Reference(To be deleted later)'])
df['District of Reference(To be deleted later)'].value_counts()
# Out:
# 8     113
# 0      91
# 2      89
# 5      88
# 7      87
# 4      84
# 3      79
# 1      79
# 10     77
# 6      63
# 9      50
# Name: District of Reference(To be deleted later), dtype: int64

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import seaborn as sns
X_train = df[['Rating', 'District of Reference(To be deleted later)']]
clustering = DBSCAN(eps=12.5, min_samples=4).fit(X_train)
DBSCAN_dataset = X_train.copy()
DBSCAN_dataset.loc[:,'Cluster'] = clustering.labels_ 
DBSCAN_dataset.Cluster.value_counts().to_frame()
outliers = DBSCAN_dataset[DBSCAN_dataset['Cluster']==-1]

fig2, (axes) = plt.subplots(1,2,figsize=(12,5))

sns.scatterplot('Rating', 'District of Reference(To be deleted later)',

                data=DBSCAN_dataset[DBSCAN_dataset['Cluster']!=-1],

                hue='Cluster', ax=axes[0], palette='Set2', legend='full', s=200)
axes[0].scatter(outliers['Rating'], outliers['District of Reference(To be deleted later)'], s=10, label='outliers', c="k")
axes[0].legend()
plt.setp(axes[0].get_legend().get_texts(), fontsize='12')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from joblib import Parallel, delayed
import joblib
  
  
# Save the model as a pickle in a file
joblib.dump(clustering, 'model2.pkl')
# Out:
# ['model2.pkl']

# %%
# region 9 has is more porsche area becuase the rating of restuarants here are mostly of 4star to 5 star
# in region8 all type of good restaurnts are there we can say there we found more competiotion among restarants 
# and and more variety as well

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import seaborn as sns
X_train = df[['Price for 2', 'District of Reference(To be deleted later)']]
clustering = DBSCAN(eps=12.5, min_samples=4).fit(X_train)
DBSCAN_dataset = X_train.copy()
DBSCAN_dataset.loc[:,'Cluster'] = clustering.labels_ 
DBSCAN_dataset.Cluster.value_counts().to_frame()
outliers = DBSCAN_dataset[DBSCAN_dataset['Cluster']==-1]

fig2, (axes) = plt.subplots(1,2,figsize=(12,5))

sns.scatterplot('Price for 2', 'District of Reference(To be deleted later)',

                data=DBSCAN_dataset[DBSCAN_dataset['Cluster']!=-1],

                hue='Cluster', ax=axes[0], palette='Set2', legend='full', s=200)
axes[0].scatter(outliers['Price for 2'], outliers['District of Reference(To be deleted later)'], s=10, label='outliers', c="k")
axes[0].legend()
plt.setp(axes[0].get_legend().get_texts(), fontsize='12')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from joblib import Parallel, delayed
import joblib
  
  
# Save the model as a pickle in a file
joblib.dump(clustering, 'model3.pkl')
# Out:
# ['model3.pkl']

# %%
# most the restuarnts have price for 2 < 700

# %%
A=[]
A=df['Cuisines'].unique()
# print(listA.split(","))
# print(type(A[3]))
# print( list(A[3].split(",")))
# size 1 -> 
count=0
for j in A:
    if(len(list(j.split(","))) == 1):
        count+=1
print(count)
# Out:
# 25

# %%
items = set()
for j in A:
    j=j.strip()
#     print(len(list(j.split(","))))
    if(len(list(j.split(","))) == 1 ):
#         ['Bakery']
        S = ""
        for i in j:
#             print(i)
            if(i == ']' or i=='['):
                continue
            else:
                S += i
        items.add(S)
    if(len(list(j.split(","))) == 2 ):
#         print(j)
        S = ""
        for i in j:
            if(i == ','):
#                 print(S)
                items.add(S)
                S=""
            elif(i == ']' or i=='['):
                continue
            else:
                S += i
#         print(S)
        items.add(S)



print(items)
# Out:
# {"'Thalis'", " 'Juices'", "'European'", " 'Burgers'", " 'Indian'", " 'Thai'", " 'Pan-Asian'", " 'South Indian'", " 'Navratri Special'", " 'Mexican'", "'Street Food'", "'Desserts'", "'Bakery'", "'Chinese'", " 'African'", " 'Chinese'", " 'Continental'", "'Maharashtrian'", " 'Beverages'", "'Lebanese'", "'Chaat'", " 'Snacks'", " 'Italian-American'", "'Paan'", "'Italian'", "'Biryani'", "'Tandoor'", " 'Desserts'", "'Indian'", " 'Ice Cream Cakes'", " 'Keto'", " 'Street Food'", " 'Fast Food'", "'Portuguese'", " 'Hyderabadi'", "'Snacks'", "'Sweets'", " 'Ice Cream'", "'Punjabi'", " 'Sweets'", " 'Bakery'", " 'Salads'", " 'Bihari'", " 'Asian'", "'Burgers'", "'Healthy Food'", "'Pastas'", " 'Mughlai'", "'Cafe'", "'Japanese'", "'Ice Cream'", " 'Italian'", "'Pan-Asian'", "'Salads'", " 'North Indian'", " 'Thalis'", " 'Kebabs'", " 'Pastas'", "'Asian'", "'Arabian'", "'Beverages'", " 'Pizzas'", "'Pizzas'", "'American'", "'Kebabs'", " 'Healthy Food'", " 'Tandoor'", "'Mughlai'", "'Fast Food'", " 'Biryani'
# ...

# %%
import matplotlib.pyplot as plt

for S in items:
    for colname in  df:
        arr=[]
        name=[]
        rating=[]
        area=[]
        if(colname == "Cuisines"):
            for (index,s) in enumerate(df[colname]):
                if(s.find(S) >= 0):
                    name.append(df.iloc[index]["Restaurant Name"])
                    arr.append(df.iloc[index]["Price for 2"])
                    rating.append(df.iloc[index]["Rating"])
                    area.append(df.iloc[index]["District of Reference(To be deleted later)"])
    #         print(arr)
    #         print(name)
    #         print(rating)
            fig = plt.figure(figsize = (100, 50))
            plt.bar(name, rating, color ='blue',width = 0.4)
            plt.xlabel("Restaurant Name",fontsize = 100)
            plt.ylabel("Rating",fontsize = 100)
            plt.title(f"Name vs Rating for {S} restuarants",fontsize = 100)
            plt.show()

            fig = plt.figure(figsize = (100, 50))
            plt.bar(area, arr, color ='green',width = 0.4)
            plt.xlabel("Area",fontsize = 100)
            plt.ylabel("Price for 2",fontsize = 100)
            plt.title(f"Area vs Price for {S} restuarants",fontsize = 100)
            plt.show()

# %%
plt.savefig('books_read.png')

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1d90405-7c57-4c1a-baa1-4397b0ab431b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1d90405-7c57-4c1a-baa1-4397b0ab431b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
   
# create a new data frame
df3 = pd.read_csv("/content/Bonus_Data - Bonus_Data.csv")

   
print("Given Dataframe is :\n",df)
  
print("\nSplitting Name column into two different columns :") 
df3 = (df3["Coordinates"].apply(lambda x: pd.Series(str(x).split(","))))
df3.to_csv("Coordinatessplit5.csv")
df3.head
# Out:
# Given Dataframe is :
#       Unnamed: 0          0          1                   geometry
# 0             0  28.669413  77.195266  POINT (77.19527 28.66941)
# 1             1  28.734451  77.114137  POINT (77.11414 28.73445)
# 2             2  28.743151  77.196723  POINT (77.19672 28.74315)
# 3             3  28.334931  77.327502  POINT (77.32750 28.33493)
# 4             4  28.472435  77.314962  POINT (77.31496 28.47244)
# ..          ...        ...        ...                        ...
# 895         895  28.550067  77.120684  POINT (77.12068 28.55007)
# 896         896  28.554663  77.173637  POINT (77.17364 28.55466)
# 897         897  28.557929  77.171606  POINT (77.17161 28.55793)
# 898         898  28.899900  77.113900  POINT (77.11390 28.89990)
# 899         899  28.724700  77.062429  POINT (77.06243 28.72470)
#
# [900 rows x 4 columns]
#
# Splitting Name column into two different columns :
# <bound method NDFrame.head of                       0                  1
# ...

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 52.2 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 39.4 MB/s
# ...

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

df = pd.read_csv("/content/Coordinatessplit5.csv", delimiter=',', skiprows=0, low_memory=False)

geometry = [Point(xy) for xy in zip(df['1'], df['0'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-84927dc26a2b> in <module>
#      11 #this is a simple map that goes with geopandas
#      12 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---> 13 gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15,dpi=300);
#
# /usr/local/lib/python3.8/dist-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     966         kind = kwargs.pop("kind", "geo")
#     967         if kind == "geo":
# --> 968             return plot_dataframe(data, *args, **kwargs)
#     969         if kind in self._pandas_kinds:
#     970             # Access pandas plots
#
# ...

# %%
pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# list1=[]
# for i in len(a):
print(df3.head())
print(df.head())
concat_data = pd.concat([df3, df], ignore_index=True)
print(concat_data)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5745a1f-d0a0-4d69-94a8-b886c041adb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5745a1f-d0a0-4d69-94a8-b886c041adb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# for i in range(1,len(area)):
#   print(area)
count = 0
bonusdata = pd.read_csv("/content/Bonus_Data - Bonus_Data (1).csv")
list_Xcoord =[]
list_Ycoord=[]
list_coor=[]
for i in range(1,a):
  if("Maharashtrian" in bonusdata.iloc[i]["Cuisines"]):
    count+=1
    list_coor.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
    # list_Xcoord.append(bonusdata.iloc[i][""])
    # list_Ycoord.append(bonusdata.iloc[i]["Y-coord"])

print(list_Xcoord)
print(list_Ycoord)
print(list_coor)
print(count)

map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coor:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
map_new.save('maharashtrian_coordinates.html')
# Out:
# []
# []
# [[28.54349, 77.1295], [28.6702257, 77.1332829], [28.6702257, 77.1332829]]
# 3

# %%
print(items)
# Out:
# {"'Thalis'", " 'Juices'", "'European'", " 'Burgers'", " 'Indian'", " 'Thai'", " 'Pan-Asian'", " 'South Indian'", " 'Navratri Special'", " 'Mexican'", "'Street Food'", "'Desserts'", "'Bakery'", "'Chinese'", " 'African'", " 'Chinese'", " 'Continental'", "'Maharashtrian'", " 'Beverages'", "'Lebanese'", "'Chaat'", " 'Snacks'", " 'Italian-American'", "'Paan'", "'Italian'", "'Biryani'", "'Tandoor'", " 'Desserts'", "'Indian'", " 'Ice Cream Cakes'", " 'Keto'", " 'Street Food'", " 'Fast Food'", "'Portuguese'", " 'Hyderabadi'", "'Snacks'", "'Sweets'", " 'Ice Cream'", "'Punjabi'", " 'Sweets'", " 'Bakery'", " 'Salads'", " 'Bihari'", " 'Asian'", "'Burgers'", "'Healthy Food'", "'Pastas'", " 'Mughlai'", "'Cafe'", "'Japanese'", "'Ice Cream'", " 'Italian'", "'Pan-Asian'", "'Salads'", " 'North Indian'", " 'Thalis'", " 'Kebabs'", " 'Pastas'", "'Asian'", "'Arabian'", "'Beverages'", " 'Pizzas'", "'Pizzas'", "'American'", "'Kebabs'", " 'Healthy Food'", " 'Tandoor'", "'Mughlai'", "'Fast Food'", " 'Biryani'
# ...

# %%
list_coor1=[]
list_coor2=[]
list_coor3=[]
list_coor4=[]
list_coor5=[]
list_coor6=[]
list_coor7=[]
list_coor8=[]
list_coor9=[]
list_coor10=[]
list_coor11=[]
for i in range(1,a):
  if("North Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor1.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif ("Central Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor2.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("East Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor3.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("New Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor4.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif ("North East Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor5.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("North West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor6.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("Shahdara" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor7.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("South Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor8.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("South East Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor9.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("South West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor10.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    list_coor11.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())

map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coor1:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
for i in list_coor2:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='red')))
for i in list_coor3:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='blue')))
for i in list_coor4:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='yellow')))
for i in list_coor5:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='black')))
for i in list_coor6:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='purple')))
for i in list_coor7:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='pink')))
for i in list_coor8:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='grey')))
for i in list_coor9:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='white')))
for i in list_coor10:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='orange')))
    
for i in list_coor11:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='teal')))
    
map_new.save('all_coordinates.html')
# Out:
# <ipython-input-75-b230842b461f>:49: UserWarning: color argument of Icon should be one of: {'black', 'darkred', 'green', 'beige', 'lightblue', 'pink', 'orange', 'white', 'lightred', 'lightgreen', 'blue', 'lightgray', 'darkpurple', 'cadetblue', 'darkblue', 'red', 'darkgreen', 'purple', 'gray'}.
#   popup=i[0],icon=folium.Icon(color='yellow')))
# <ipython-input-75-b230842b461f>:61: UserWarning: color argument of Icon should be one of: {'black', 'darkred', 'green', 'beige', 'lightblue', 'pink', 'orange', 'white', 'lightred', 'lightgreen', 'blue', 'lightgray', 'darkpurple', 'cadetblue', 'darkblue', 'red', 'darkgreen', 'purple', 'gray'}.
#   popup=i[0],icon=folium.Icon(color='grey')))
# <ipython-input-75-b230842b461f>:71: UserWarning: color argument of Icon should be one of: {'black', 'darkred', 'green', 'beige', 'lightblue', 'pink', 'orange', 'white', 'lightred', 'lightgreen', 'blue', 'lightgray', 'darkpurple', 'cadetblue', 'darkblue', 'red', 'darkgreen', 'purple', 'gray'}.
# ...

# %%
# converting the items into a list 
# for i in range(1,len(area)):
#   print(area)
count = 0
bonusdata = pd.read_csv("/content/Bonus_Data - Bonus_Data (1).csv")
list_Xcoord =[]
list_Ycoord=[]
list_coor=[]
for i in range(1,a):
  if("Burgers" in bonusdata.iloc[i]["Cuisines"]):
    count+=1
    list_coor.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
    # list_Xcoord.append(bonusdata.iloc[i][""])
    # list_Ycoord.append(bonusdata.iloc[i]["Y-coord"])

print(list_Xcoord)
print(list_Ycoord)
print(list_coor)
print(count)

map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coor:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
map_new.save('burgers_coordinates.html')
# Out:
# []
# []
# [[28.72943, 77.08625], [28.69608, 77.204297], [28.719087, 77.1340476], [28.550292, 77.2053892], [28.5889237, 77.1687266], [28.6661203, 77.1274968], [28.6661203, 77.1274968], [28.3834011, 77.0520493], [28.5763677, 77.1945781], [28.6429033, 77.2223967], [28.7004266, 77.1168843], [28.7167385, 77.1708098]]
# 12

# %%
count = 0
count1= 0
price =0
bonusdata = pd.read_csv("/content/Bonus_Data - Bonus_Data (1).csv")
list_Xcoord =[]
list_Ycoord=[]
list_coor=[]
list_coor1=[]
for i in range(1,a):
  if("South West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]):
    count+=1
    price+=bonusdata.iloc[i]["Price for 2"]


# 50 - count
# 18100 - price
# 362.0 - average 
for i in range(1,a):
  if("South West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and bonusdata.iloc[i]["Price for 2"]<= 362):
    count1+=1


for i in range(1,a):
  if(bonusdata.iloc[i]["Price for 2"]<= 362):
    count1+=1
    list_coor.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())

for i in range(1,a):
  if(bonusdata.iloc[i]["Price for 2"]>362):
    count1+=1
    list_coor1.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())


map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coor:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
for i in list_coor1:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='red')))
map_new.save('cheaperthansouthdelhi.html')

# %%
count3 = 0
price3=0
list_coorcheap=[]
list_coormid=[]
list_coorexp=[]
bonusdata = pd.read_csv("/content/Bonus_Data - Bonus_Data (1).csv")

for i in range(1,a):
    count3+=1
    price3+=bonusdata.iloc[i]["Price for 2"]
  
print(count3)
print(price3)
print(price3/count3)

# 899
# 264834
# 294.587319243604 - averqage 
#  250 - median 


for i in range(1,a):
  if(bonusdata.iloc[i]["Price for 2"]<250 ):
    # count1+=1
    list_coorcheap.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())


for i in range(1,a):
  if(bonusdata.iloc[i]["Price for 2"]>=250 and bonusdata.iloc[i]["Price for 2"]< 294.587319243604):
    # count1+=1
    list_coormid.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())

for i in range(1,a):
  if(bonusdata.iloc[i]["Price for 2"]>294.587319243604):
    # count1+=1
    list_coorexp.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())



map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coorcheap:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
for i in list_coormid:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='pink')))
for i in list_coorexp:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='red')))
map_new.save('restaurantrangesindelhi.html')
# Out:
# 899
# 264834
# 294.587319243604

# %%
# count3 = 0
# price3=0
list_coorbad=[]
list_coormid1=[]
list_coorgood=[]
bonusdata = pd.read_csv("/content/Bonus_Data - Bonus_Data (1).csv")

# for i in range(1,a):
#     count3+=1
#     price3+=bonusdata.iloc[i]["Price for 2"]
  
# print(count3)
# print(price3)
# print(price3/count3)


# 3.048- averqage 
# 3.95 - median 


for i in range(1,a):
  if(bonusdata.iloc[i]["Rating"]<3.048 ):
    # count1+=1
    list_coorbad.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())


for i in range(1,a):
  if(bonusdata.iloc[i]["Rating"]>=3.048 and bonusdata.iloc[i]["Rating"]< 3.95):
    # count1+=1
    list_coormid1.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())

for i in range(1,a):
  if(bonusdata.iloc[i]["Rating"]>3.95):
    # count1+=1
    list_coorgood.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())



map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coorbad:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
for i in list_coormid1:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='pink')))
for i in list_coorgood:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='red')))
map_new.save('qualitybasisrestaurantrangesindelhi.html')

# %%
list_coor1=[]
list_coor2=[]
list_coor3=[]
list_coor4=[]
list_coor5=[]
list_coor6=[]
list_coor7=[]
list_coor8=[]
list_coor9=[]
list_coor10=[]
list_coor11=[]
for i in range(1,a):
  if("North Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and  "Bakery" in bonusdata.iloc[i]["Cuisines"]  ):
    list_coor1.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif ("Central Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]and "Bakery" in bonusdata.iloc[i]["Cuisines"] ):
    list_coor2.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("East Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"]and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor3.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("New Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor4.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif ("North East Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor5.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("North West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor6.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("Shahdara" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor7.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("South Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor8.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("South East Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor9.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("South West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor10.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())
  elif("West Delhi" in bonusdata.iloc[i]["District of Reference(To be deleted later)"] and "Bakery" in bonusdata.iloc[i]["Cuisines"]):
    list_coor11.append(bonusdata.iloc[i][['X-coord','Y-coord']].values.tolist())


print(list_coor1)
print(list_coor2)
print(list_coor3)
print(list_coor4)
print(list_coor5)
print(list_coor6)
print(list_coor7)
print(list_coor8)
print(list_coor9)
print(list_coor10)
print(list_coor11)
map_new=folium.Map()
# list_coor=df[['0','1']].values.tolist()
for i in list_coor1:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='green')))
for i in list_coor2:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='red')))
for i in list_coor3:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='blue')))
for i in list_coor4:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='beige')))
for i in list_coor5:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='lightgreen')))
for i in list_coor6:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='purple')))
for i in list_coor7:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='pink')))
for i in list_coor8:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='lightred')))
for i in list_coor9:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='darkred')))
for i in list_coor10:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='orange')))
    
for i in list_coor11:
    map_new.add_child(folium.Marker(location=[i[0],i[1]],
                                popup=i[0],icon=folium.Icon(color='cadetblue')))
    
map_new.save('bakeryanddessertsinsectors.html')
# Out:
# [[28.7565094, 77.197125], [28.731722, 77.160083], [28.70218, 77.183151], [28.7446127, 77.118123], [28.7136963, 77.1765945], [28.714406, 77.176619], [28.7643698, 77.1823874], [28.703038, 77.193816]]
# [[28.6341707, 77.2179749], [28.6341707, 77.2179749], [28.6777115, 77.2051113], [28.637214, 77.229385], [28.6679548, 77.2086824], [28.705206, 77.195394], [28.703038, 77.193816], [28.6477937, 77.1928065]]
# ...
